# %%
import pandas as pd
#for visualization
import matplotlib.pyplot as plt
import seaborn as sns

df= pd.read_csv(r'C:\Users\Tema\Documents\10Academy\rating.csv')
df2 = pd.read_csv(r'C:\Users\Tema\Documents\10Academy\traffic.csv')
df3 = pd.read_csv(r'C:\Users\Tema\Documents\10Academy\domains_location.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58356 entries, 0 to 58355
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   article_id       58356 non-null  int64
#  1   source_id        17771 non-null  object
#  2   source_name      58356 non-null  object
#  3   author           56193 non-null  object
#  4   title            58356 non-null  object
#  5   description      58346 non-null  object
#  6   url              58356 non-null  object
#  7   url_to_image     54905 non-null  object
#  8   published_at     58356 non-null  object
#  9   content          58356 non-null  object
#  10  category         58335 non-null  object
#  11  article          58356 non-null  object
#  12  title_sentiment  58356 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 5.8+ MB

# %%
df
# Out:
#        article_id source_id         source_name  \
# 0           81664       NaN              Forbes
# 1           81667       NaN                 CNA
# 2           81694      time                Time
# 3           81695       NaN            Phys.Org
# 4           81703       NaN      Digital Trends
# ...           ...       ...                 ...
# 58351      781108       NaN  The Indian Express
# 58352      781129       NaN              Forbes
# 58353      781235       NaN                 NPR
# 58354      781240       NaN              Forbes
# 58355      781308       NaN              Forbes
#
#                                                   author  \
# 0      Elizabeth Brownfield, Contributor, \n Elizabet...
# 1                                                    NaN
# 2                                  Christina Larson / AP
# 3                                           Sara Schmidt
# 4                                           Jason Struss
# ...

# %%
df2
# Out:
#         GlobalRank  TldRank                  Domain  TLD  RefSubNets   RefIPs  \
# 0                1        1              google.com  com      471274  2151358
# 1                2        2            facebook.com  com      465424  2250631
# 2                3        3             youtube.com  com      420579  1852995
# 3                4        4             twitter.com  com      404985  1757127
# 4                5        5           instagram.com  com      364746  1598085
# ...            ...      ...                     ...  ...         ...      ...
# 999995      999996   485324              kireie.com  com         222      280
# 999996      999997   485325             mt-lock.com  com         222      280
# 999997      999998   485326           pinkwater.com  com         222      280
# 999998      999999   485327          soderhomes.com  com         222      280
# 999999     1000000   485328  toyotamusicfactory.com  com         222      280
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37802 entries, 0 to 37801
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SourceCommonName  37802 non-null  object
#  1   location          37802 non-null  object
#  2   Country           37801 non-null  object
# dtypes: object(3)
# memory usage: 886.1+ KB

# %%
df2.isnull().sum()
# Out:
# GlobalRank        0
# TldRank           0
# Domain            0
# TLD               0
# RefSubNets        0
# RefIPs            0
# IDN_Domain        0
# IDN_TLD           0
# PrevGlobalRank    0
# PrevTldRank       0
# PrevRefSubNets    0
# PrevRefIPs        0
# dtype: int64

# %%
#Top 10 websites with the largest article counts
df2['Domain'].head(10)
# Out:
# 0              google.com
# 1            facebook.com
# 2             youtube.com
# 3             twitter.com
# 4           instagram.com
# 5            linkedin.com
# 6               apple.com
# 7           microsoft.com
# 8    googletagmanager.com
# 9           wikipedia.org
# Name: Domain, dtype: object

# %%
plt.figure(figsize= (8,6))
sns.countplot(data=df2, x= 'Domain')
plt.title('Top 10 websites with the largest article counts')
plt.xlabel('Websites domain')
plt.ylabel('Rank')
plt.show()

# %%
#Bottom 10 websites with the largest article counts
df2['Domain'].tail(10)
# Out:
# 999990              eiretrip.com
# 999991      exploring-africa.com
# 999992                  hmag.com
# 999993            irishcycle.com
# 999994           keith-baker.com
# 999995                kireie.com
# 999996               mt-lock.com
# 999997             pinkwater.com
# 999998            soderhomes.com
# 999999    toyotamusicfactory.com
# Name: Domain, dtype: object

# %%
df3
# Out:
#       SourceCommonName location    Country
# 0           00221.info       SG    Senegal
# 1            01net.com       FR     France
# 2             01net.it       IT      Italy
# 3          0223.com.ar       AR  Argentina
# 4         022china.com       CH      China
# ...                ...      ...        ...
# 37797      zz.diena.lv       LG     Latvia
# 37798      zz.fjnet.cn       CH      China
# 37799        zz.mnw.cn       CH      China
# 37800           zz7.it       IT      Italy
# 37801    zznews.gov.cn       CH      China
#
# [37802 rows x 3 columns]

# %%
# Top 10 countries with highst number of news media organizations 
df3['Country'].value_counts().head(10)
# Out:
# Country
# United States     14111
# United Kingdom     1950
# Italy              1810
# France             1041
# Russia             1024
# Canada              887
# Germany             884
# China               780
# Turkey              725
# India               686
# Name: count, dtype: int64

# %%
# Bottom 10 countries with highst number of news media organizations
df3['Country'].value_counts().tail(10)
# Out:
# Country
# Greenland         1
# Guernsey          1
# Isle of Man       1
# Cook Islands      1
# Guinea-Bissau     1
# Micronesia        1
# Aruba             1
# American Samoa    1
# Guadeloupe        1
# Saint Helena      1
# Name: count, dtype: int64

# %%
df3['Country'].value_counts()
# Out:
# Country
# United States     14111
# United Kingdom     1950
# Italy              1810
# France             1041
# Russia             1024
#                   ...
# Micronesia            1
# Aruba                 1
# American Samoa        1
# Guadeloupe            1
# Saint Helena          1
# Name: count, Length: 225, dtype: int64

# %%
dfdf3['Country'].value_counts()
# Out:
# Country
# United States     14111
# United Kingdom     1950
# Italy              1810
# France             1041
# Russia             1024
#                   ...
# Micronesia            1
# Aruba                 1
# American Samoa        1
# Guadeloupe            1
# Saint Helena          1
# Name: count, Length: 225, dtype: int64

# %%
# Create a sample DataFrame
#??

data = {'Country': ['Monaco', 'Madagascar', 'Mexico', 'Maldives', 'Mali', 'Barbados',
       'Nicaragua', 'Congo, The Democratic Republic of the',
       'North Macedonia', 'Malta', 'Poland', 'Myanmar',
       'Russian Federation', 'Mongolia', 'Montenegro', 'Malaysia',
       'Romania', 'Mozambique', 'Montserrat', 'South Sudan', 'News',
       'Israel', 'Mauritania', 'Mauritius', 'Netherlands', 'Martinique',
       'Malawi', 'Germany', 'Niger', 'Namibia', 'Nigeria', 'Georgia',
       'Nepal', 'Facebook', 'Norway', 'COVID', 'Peru', 'Travel',
       'History', 'Papua New Guinea', 'New Zealand', 'Sports', 'Oman',
       'Pakistan', 'Panama', 'Love', 'America', 'Philippines', 'Palau',
       'Politics', 'Armenia', 'Food', 'Sudan', 'Puerto Rico', 'Weather',
       'Real estate', 'Cars', 'Senegal', 'Singapore', 'Stock', 'Ghana',
       'TikTok', 'Photography', 'Kazakhstan', 'Games', 'Climate', 'Space',
       'Somalia', 'Tonga', 'Architecture', 'Art', 'Africa',
       'Relationships', 'Qatar', 'world', 'Beauty', 'Podcasts', 'Yoga',
       'Coding', 'Cryptocurrency', 'Nutrition', 'Design',
       'Sustainability', 'Blockchain', 'Startups',
       'Artificial Intelligence', 'Motivation', 'Hiking', 'Productivity',
       'Health', 'Philosophy', 'Europe', 'Serbia', 'Google', 'YouTube',
       'Amazon', 'Jobs', 'Movies', 'Music', 'Technology', 'Sweden',
       'Bitcoin', 'Finance', 'Fashion', 'Instagram', 'Fitness', 'Science',
       'Education', 'Home', 'Asia', 'Portugal', 'Paraguay', 'Pets',
       'Palestine, State of', 'Rwanda', 'Saudi Arabia', 'Sierra Leone',
       'El Salvador', 'San Marino', 'Suriname', 'Slovakia', 'Ukraine',
       'Slovenia', 'Seychelles', 'Tunisia', 'United States', 'Turkey',
       'Taiwan, Province of China', 'Uganda', 'Uruguay', 'Uzbekistan',
       'Yemen', 'Samoa', 'Virgin Islands, U.S.', 'Viet Nam', 'Vanuatu',
       'South Africa', 'Zambia', 'Zimbabwe', 'Thailand', 'Tajikistan',
       'Chad', 'Turkmenistan', 'Recipes', 'Austria', 'DIY', 'Psychology',
       'Virtual Reality', 'Australia', 'Meditation', 'Gardening', 'Vegan',
       'Parenting', 'Anime', 'Mindfulness', 'Bangladesh', 'Djibouti',
       'Entrepreneurship', 'Azerbaijan', 'Belarus', 'Lithuania', 'Poetry',
       'Happiness', 'Canada', 'Minimalism', 'Astronomy', 'Guam',
       'Afghanistan', 'Aruba', 'United Arab Emirates', 'Angola',
       'Andorra', 'Albania', 'Hungary', 'Guernsey', 'Antarctica',
       'Argentina', 'Switzerland', 'Haiti', 'Burundi', 'Belgium', 'China',
       'Benin', 'Iraq', 'Burkina Faso', 'Latvia', 'Bulgaria', 'Bahrain',
       'Bahamas', 'Bosnia and Herzegovina', 'Botswana', 'Belize',
       'Brazil', 'Bermuda', 'Central African Republic', 'Cyprus',
       'Bhutan', 'Chile', "Côte d'Ivoire", 'Cameroon', 'Congo',
       'Colombia', 'Christmas Island', 'Cabo Verde', 'Costa Rica', 'Cuba',
       'Cayman Islands', 'Denmark', 'Egypt', 'Dominican Republic',
       'Kenya', 'Algeria', 'Eritrea', 'Ecuador', 'Iceland', 'Spain',
       'Estonia', 'Ethiopia', 'Finland', 'Fiji', 'France', 'Gabon',
       'Cambodia', 'Libya', 'United Kingdom', 'Gibraltar', 'Guinea',
       'Gambia', 'Greece', 'Iran, Islamic Republic of', 'Guatemala',
       'Greenland', 'India', 'Guyana', 'Hong Kong', 'Luxembourg',
       'Honduras', 'Croatia', 'Indonesia', 'Isle of Man', 'Ireland',
       'Jersey', 'Italy', 'Jamaica', 'Jordan', 'Kyrgyzstan', 'Japan',
       'Korea, Republic of', 'Lebanon', 'Kuwait', 'Liberia',
       'Liechtenstein', 'Sri Lanka', 'Morocco', 'Macao', 'Réunion'],
        'Continent': ['Africa', 'EU', 'Africa', 'EU', 'Africa', 'Middle East']}

dff = pd.DataFrame(data)
continent_mapping = {'Africa': 'African', 'EU': 'EU', 'Middle East': 'Middle East'}
dff['Continent'].map(continent_mapping)
dff

# %%
df['title_sentiment'].value_counts()
# Out:
# title_sentiment
# Neutral     42926
# Negative     9133
# Positive     6297
# Name: count, dtype: int64

# %%
df
# Out:
#        article_id source_id         source_name  \
# 0           81664       NaN              Forbes
# 1           81667       NaN                 CNA
# 2           81694      time                Time
# 3           81695       NaN            Phys.Org
# 4           81703       NaN      Digital Trends
# ...           ...       ...                 ...
# 58351      781108       NaN  The Indian Express
# 58352      781129       NaN              Forbes
# 58353      781235       NaN                 NPR
# 58354      781240       NaN              Forbes
# 58355      781308       NaN              Forbes
#
#                                                   author  \
# 0      Elizabeth Brownfield, Contributor, \n Elizabet...
# 1                                                    NaN
# 2                                  Christina Larson / AP
# 3                                           Sara Schmidt
# 4                                           Jason Struss
# ...

# %%
df.describe()
# Out:
#           article_id
# count   58356.000000
# mean   298958.734492
# std    216023.477569
# min       418.000000
# 25%    121776.500000
# 50%    251651.000000
# 75%    451541.500000
# max    781308.000000

# %%
df.groupby('url').mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...
